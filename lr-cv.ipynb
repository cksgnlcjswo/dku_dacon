# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
from matplotlib import rcParams
import numpy as np
from pathlib import Path
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
import seaborn as sns
import warnings

# %%
rcParams['figure.figsize'] = (16, 8)
plt.style.use('fivethirtyeight')
pd.set_option('max_columns', 100)
pd.set_option("display.precision", 4)
warnings.simplefilter('ignore')

# %%
data_dir = Path('../input/')
feature_dir = Path('../feature/')
val_dir = Path('../txt')
tst_dir = Path('../txt')
sub_dir = Path('../submission')

trn_file = data_dir / 'train.csv'
tst_file = data_dir / 'test.csv'
sample_file = sub_dir / 'sample_submission.csv'

target_col = 'class'
n_fold = 5
n_class = 3
seed = 42

# %%
algo_name = 'lrcv'
feature_name = 'polyfeature'
model_name = f'{algo_name}_{feature_name}'

feature_file = feature_dir / f'{feature_name}.csv'
p_val_file = val_dir / f'{model_name}.val.csv'
p_tst_file = tst_dir / f'{model_name}.tst.csv'
sub_file = sub_dir / f'{model_name}.csv'

# %%
df = pd.read_csv(feature_dir / 'feature.csv', index_col=0)
print(df.shape)
df.head()
# Out:
# (400000, 26)
#           z    redshift  dered_u  dered_g  dered_r  dered_i  dered_z  \
# id
# 0   16.9396 -8.1086e-05  23.1243  20.2578  18.9551  17.6321  16.9089
# 1   13.1689  4.5061e-03  14.9664  14.0045  13.4114  13.2363  13.1347
# 2   15.3500  4.7198e-04  16.6076  15.6866  15.4400  15.3217  15.2961
# 3   19.6346  5.8143e-06  25.3536  20.9947  20.0873  19.7947  19.5552
# 4   17.9826 -3.3247e-05  23.7714  20.4338  18.8630  18.1903  17.8759
#
#     nObserve  airmass_u  class     g_r     u_g     r_i     i_z     u_r  \
# id
# 0     1.3723     1.1898    0.0  1.3273  2.9272  1.3371  0.7328  4.2545
# 1     0.5266     1.2533    1.0  0.6096  0.9902  0.1840  0.0995  1.5997
# 2     0.7413     1.0225    0.0  0.2891  0.9610  0.1428  0.0435  1.2501
# 3     0.9591     1.2054    0.0  0.9676  4.4719  0.3262  0.2603  5.4395
# 4     1.2917     1.1939    0.0  1.6568  3.7543  0.7182  0.3415  5.4111
#
#     d_dered_u  d_dered_g  d_dered_r  d_dered_i  d_dered_z  d_dered_ug  \
# id
# 0     -0.1397    -0.0790    -0.0544    -0.0403    -0.0307      2.8665
# 1     -0.0857    -0.0574    -0.0410    -0.0322    -0.0343      0.9619
# 2     -0.1787    -0.1388    -0.0963    -0.0718    -0.0540      0.9211
# 3     -0.3070    -0.1941    -0.1339    -0.1003    -0.0795      4.3590
# 4     -0.6820    -0.2653    -0.1794    -0.1339    -0.1067      3.3376
#
#     d_dered_gr  d_dered_iz  d_dered_ur  d_dered_ri  d_obs_det
# id
# 0       1.3027      0.7232      4.1691      1.3230     2.1456
# 1       0.5931      0.1016      1.5550      0.1751     1.3163
# 2       0.2466      0.0257      1.1676      0.1183     1.4821
# 3       0.9074      0.2395      5.2664      0.2926     1.4454
# 4       1.5709      0.3144      4.9084      0.6727     1.9857

# %%
scaler = StandardScaler()
poly = PolynomialFeatures(2)
X = poly.fit_transform(scaler.fit_transform(df.drop(target_col, axis=1)))
feature_names = poly.get_feature_names(df.columns)
feature_names
# Out:
# ['1',
#  'z',
#  'redshift',
#  'dered_u',
#  'dered_g',
#  'dered_r',
#  'dered_i',
#  'dered_z',
#  'nObserve',
#  'airmass_u',
#  'class',
#  'g_r',
#  'u_g',
#  'r_i',
#  'i_z',
#  'u_r',
#  'd_dered_u',
#  'd_dered_g',
#  'd_dered_r',
#  'd_dered_i',
#  'd_dered_z',
#  'd_dered_ug',
#  'd_dered_gr',
#  'd_dered_iz',
#  'd_dered_ur',
#  'd_dered_ri',
#  'z^2',
#  'z redshift',
#  'z dered_u',
#  'z dered_g',
#  'z dered_r',
#  'z dered_i',
#  'z dered_z',
#  'z nObserve',
#  'z airmass_u',
#  'z class',
#  'z g_r',
#  'z u_g',
#  'z r_i',
#  'z i_z',
#  'z u_r',
#  'z d_dered_u',
#  'z d_dered_g',
#  'z d_dered_r',
#  'z d_dered_i',
#  'z d_dered_z',
#  'z d_dered_ug',
#  'z d_dered_gr',
#  'z d_dered_iz',
#  'z d_dered_ur',
#  'z d_dered_ri',
#  'redshift^2',
#  'redshift dered_u',
#  'redshift dered_g',
#  'redshift dered_r',
#  'redshift dered_i',
#  'redshift dered_z',
#  'redshift nObserve',
#  'redshift airmass_u',
#  'redshift class',
#  'redshift g_r',
#  'redshift u_g',
#  'redshift r_i',
#  'redshift i_z',
#  'redshift u_r',
#  'redshift d_dered_u',
#  'redshift d_dered_g',
#  'redshift d_dered_r',
#  'redshift d_dered_i',
#  'redshift d_dered_z',
#  'redshift d_dered_ug',
#  'redshift d_dered_gr',
#  'redshift d_dered_iz',
#  'redshift d_dered_ur',
#  'redshift d_dered_ri',
#  'dered_u^2',
#  'dered_u dered_g',
#  'dered_u dered_r',
#  'dered_u dered_i',
#  'dered_u dered_z',
#  'dered_u nObserve',
#  'dered_u airmass_u',
#  'dered_u class',
#  'dered_u g_r',
#  'dered_u u_g',
#  'dered_u r_i',
#  'dered_u i_z',
#  'dered_u u_r',
#  'dered_u d_dered_u',
#  'dered_u d_dered_g',
#  'dered_u d_dered_r',
#  'dered_u d_dered_i',
#  'dered_u d_dered_z',
#  'dered_u d_dered_ug',
#  'dered_u d_dered_gr',
#  'dered_u d_dered_iz',
#  'dered_u d_dered_ur',
#  'dered_u d_dered_ri',
#  'dered_g^2',
#  'dered_g dered_r',
#  'dered_g dered_i',
#  'dered_g dered_z',
#  'dered_g nObserve',
#  'dered_g airmass_u',
#  'dered_g class',
#  'dered_g g_r',
#  'dered_g u_g',
#  'dered_g r_i',
#  'dered_g i_z',
#  'dered_g u_r',
#  'dered_g d_dered_u',
#  'dered_g d_dered_g',
#  'dered_g d_dered_r',
#  'dered_g d_dered_i',
#  'dered_g d_dered_z',
#  'dered_g d_dered_ug',
#  'dered_g d_dered_gr',
#  'dered_g d_dered_iz',
#  'dered_g d_dered_ur',
#  'dered_g d_dered_ri',
#  'dered_r^2',
#  'dered_r dered_i',
#  'dered_r dered_z',
#  'dered_r nObserve',
#  'dered_r airmass_u',
#  'dered_r class',
#  'dered_r g_r',
#  'dered_r u_g',
#  'dered_r r_i',
#  'dered_r i_z',
#  'dered_r u_r',
#  'dered_r d_dered_u',
#  'dered_r d_dered_g',
#  'dered_r d_dered_r',
#  'dered_r d_dered_i',
#  'dered_r d_dered_z',
#  'dered_r d_dered_ug',
#  'dered_r d_dered_gr',
#  'dered_r d_dered_iz',
#  'dered_r d_dered_ur',
#  'dered_r d_dered_ri',
#  'dered_i^2',
#  'dered_i dered_z',
#  'dered_i nObserve',
#  'dered_i airmass_u',
#  'dered_i class',
#  'dered_i g_r',
#  'dered_i u_g',
#  'dered_i r_i',
#  'dered_i i_z',
#  'dered_i u_r',
#  'dered_i d_dered_u',
#  'dered_i d_dered_g',
#  'dered_i d_dered_r',
#  'dered_i d_dered_i',
#  'dered_i d_dered_z',
#  'dered_i d_dered_ug',
#  'dered_i d_dered_gr',
#  'dered_i d_dered_iz',
#  'dered_i d_dered_ur',
#  'dered_i d_dered_ri',
#  'dered_z^2',
#  'dered_z nObserve',
#  'dered_z airmass_u',
#  'dered_z class',
#  'dered_z g_r',
#  'dered_z u_g',
#  'dered_z r_i',
#  'dered_z i_z',
#  'dered_z u_r',
#  'dered_z d_dered_u',
#  'dered_z d_dered_g',
#  'dered_z d_dered_r',
#  'dered_z d_dered_i',
#  'dered_z d_dered_z',
#  'dered_z d_dered_ug',
#  'dered_z d_dered_gr',
#  'dered_z d_dered_iz',
#  'dered_z d_dered_ur',
#  'dered_z d_dered_ri',
#  'nObserve^2',
#  'nObserve airmass_u',
#  'nObserve class',
#  'nObserve g_r',
#  'nObserve u_g',
#  'nObserve r_i',
#  'nObserve i_z',
#  'nObserve u_r',
#  'nObserve d_dered_u',
#  'nObserve d_dered_g',
#  'nObserve d_dered_r',
#  'nObserve d_dered_i',
#  'nObserve d_dered_z',
#  'nObserve d_dered_ug',
#  'nObserve d_dered_gr',
#  'nObserve d_dered_iz',
#  'nObserve d_dered_ur',
#  'nObserve d_dered_ri',
#  'airmass_u^2',
#  'airmass_u class',
#  'airmass_u g_r',
#  'airmass_u u_g',
#  'airmass_u r_i',
#  'airmass_u i_z',
#  'airmass_u u_r',
#  'airmass_u d_dered_u',
#  'airmass_u d_dered_g',
#  'airmass_u d_dered_r',
#  'airmass_u d_dered_i',
#  'airmass_u d_dered_z',
#  'airmass_u d_dered_ug',
#  'airmass_u d_dered_gr',
#  'airmass_u d_dered_iz',
#  'airmass_u d_dered_ur',
#  'airmass_u d_dered_ri',
#  'class^2',
#  'class g_r',
#  'class u_g',
#  'class r_i',
#  'class i_z',
#  'class u_r',
#  'class d_dered_u',
#  'class d_dered_g',
#  'class d_dered_r',
#  'class d_dered_i',
#  'class d_dered_z',
#  'class d_dered_ug',
#  'class d_dered_gr',
#  'class d_dered_iz',
#  'class d_dered_ur',
#  'class d_dered_ri',
#  'g_r^2',
#  'g_r u_g',
#  'g_r r_i',
#  'g_r i_z',
#  'g_r u_r',
#  'g_r d_dered_u',
#  'g_r d_dered_g',
#  'g_r d_dered_r',
#  'g_r d_dered_i',
#  'g_r d_dered_z',
#  'g_r d_dered_ug',
#  'g_r d_dered_gr',
#  'g_r d_dered_iz',
#  'g_r d_dered_ur',
#  'g_r d_dered_ri',
#  'u_g^2',
#  'u_g r_i',
#  'u_g i_z',
#  'u_g u_r',
#  'u_g d_dered_u',
#  'u_g d_dered_g',
#  'u_g d_dered_r',
#  'u_g d_dered_i',
#  'u_g d_dered_z',
#  'u_g d_dered_ug',
#  'u_g d_dered_gr',
#  'u_g d_dered_iz',
#  'u_g d_dered_ur',
#  'u_g d_dered_ri',
#  'r_i^2',
#  'r_i i_z',
#  'r_i u_r',
#  'r_i d_dered_u',
#  'r_i d_dered_g',
#  'r_i d_dered_r',
#  'r_i d_dered_i',
#  'r_i d_dered_z',
#  'r_i d_dered_ug',
#  'r_i d_dered_gr',
#  'r_i d_dered_iz',
#  'r_i d_dered_ur',
#  'r_i d_dered_ri',
#  'i_z^2',
#  'i_z u_r',
#  'i_z d_dered_u',
#  'i_z d_dered_g',
#  'i_z d_dered_r',
#  'i_z d_dered_i',
#  'i_z d_dered_z',
#  'i_z d_dered_ug',
#  'i_z d_dered_gr',
#  'i_z d_dered_iz',
#  'i_z d_dered_ur',
#  'i_z d_dered_ri',
#  'u_r^2',
#  'u_r d_dered_u',
#  'u_r d_dered_g',
#  'u_r d_dered_r',
#  'u_r d_dered_i',
#  'u_r d_dered_z',
#  'u_r d_dered_ug',
#  'u_r d_dered_gr',
#  'u_r d_dered_iz',
#  'u_r d_dered_ur',
#  'u_r d_dered_ri',
#  'd_dered_u^2',
#  'd_dered_u d_dered_g',
#  'd_dered_u d_dered_r',
#  'd_dered_u d_dered_i',
#  'd_dered_u d_dered_z',
#  'd_dered_u d_dered_ug',
#  'd_dered_u d_dered_gr',
#  'd_dered_u d_dered_iz',
#  'd_dered_u d_dered_ur',
#  'd_dered_u d_dered_ri',
#  'd_dered_g^2',
#  'd_dered_g d_dered_r',
#  'd_dered_g d_dered_i',
#  'd_dered_g d_dered_z',
#  'd_dered_g d_dered_ug',
#  'd_dered_g d_dered_gr',
#  'd_dered_g d_dered_iz',
#  'd_dered_g d_dered_ur',
#  'd_dered_g d_dered_ri',
#  'd_dered_r^2',
#  'd_dered_r d_dered_i',
#  'd_dered_r d_dered_z',
#  'd_dered_r d_dered_ug',
#  'd_dered_r d_dered_gr',
#  'd_dered_r d_dered_iz',
#  'd_dered_r d_dered_ur',
#  'd_dered_r d_dered_ri',
#  'd_dered_i^2',
#  'd_dered_i d_dered_z',
#  'd_dered_i d_dered_ug',
#  'd_dered_i d_dered_gr',
#  'd_dered_i d_dered_iz',
#  'd_dered_i d_dered_ur',
#  'd_dered_i d_dered_ri',
#  'd_dered_z^2',
#  'd_dered_z d_dered_ug',
#  'd_dered_z d_dered_gr',
#  'd_dered_z d_dered_iz',
#  'd_dered_z d_dered_ur',
#  'd_dered_z d_dered_ri',
#  'd_dered_ug^2',
#  'd_dered_ug d_dered_gr',
#  'd_dered_ug d_dered_iz',
#  'd_dered_ug d_dered_ur',
#  'd_dered_ug d_dered_ri',
#  'd_dered_gr^2',
#  'd_dered_gr d_dered_iz',
#  'd_dered_gr d_dered_ur',
#  'd_dered_gr d_dered_ri',
#  'd_dered_iz^2',
#  'd_dered_iz d_dered_ur',
#  'd_dered_iz d_dered_ri',
#  'd_dered_ur^2',
#  'd_dered_ur d_dered_ri',
#  'd_dered_ri^2']

# %%
df_poly = pd.DataFrame(data=X, columns=feature_names, index=df.index)
df_poly[target_col] = df[target_col]
df_poly.head()
df_poly.to_csv(feature_file)

# %%
del df_poly, df

# %%
df = pd.read_csv(feature_file, index_col=0)
print(df.shape)
df.head()
# Out:
# (400000, 351)
#       1       z  redshift  dered_u  dered_g  dered_r  dered_i  dered_z  \
# id
# 0   1.0  0.0002   -0.1093   1.8170   0.1270   0.9086   0.0208   0.0011
# 1   1.0 -0.0719   -0.1007  -2.4251  -0.2656  -2.8534  -0.1751  -0.1054
# 2   1.0 -0.0302   -0.1082  -1.5717  -0.1600  -1.4768  -0.0822  -0.0444
# 3   1.0  0.0517   -0.1091   2.9763   0.1733   1.6769   0.1172   0.0758
# 4   1.0  0.0201   -0.1092   2.1535   0.1381   0.8461   0.0457   0.0284
#
#     nObserve  airmass_u  class     g_r     u_g     r_i     i_z     u_r  \
# id
# 0     1.5879     0.1200    0.0  0.0526  0.0170  0.0202  1.8876  0.1203
# 1    -1.0018     0.6658    1.0 -0.0171 -0.0075 -0.0075 -0.4572  0.1974
# 2    -0.3444    -1.3179    0.0 -0.0181 -0.0084 -0.0099 -0.7660  0.0645
# 3     0.3227     0.2544    0.0  0.1082 -0.0045 -0.0005  2.9343 -0.1189
# 4     1.3412     0.1560    0.0  0.0823  0.0039  0.0031  2.9092 -0.6550
#
#     d_dered_u  d_dered_g  d_dered_r  d_dered_i  d_dered_z  d_dered_ug  \
# id
# 0      0.0063     0.1783    -0.0002     0.0008     0.0928      0.0432
# 1      0.0081     0.2144     0.0001     0.0007    -0.0274     -0.0016
# 2      0.0013     0.0650    -0.0015     0.0002    -0.0299     -0.0235
# 3     -0.0033    -0.0366    -0.0026    -0.0005     0.1869      0.0182
# 4     -0.0093    -0.1596    -0.0039    -0.0013     0.1225      0.0601
#
#     d_dered_gr  d_dered_iz  d_dered_ur  d_dered_ri         z^2  z redshift  \
# id
# 0       0.0156      2.0425      0.0389      1.6489  3.4181e-08 -2.0203e-05
# 1      -0.0071     -0.4348     -0.0123     -0.8641  5.1738e-03  7.2464e-03
# 2      -0.0099     -0.8020     -0.0148     -0.3618  9.1298e-04  3.2708e-03
# 3      -0.0021      3.0823     -0.0071     -0.4730  2.6757e-03 -5.6442e-03
# 4       0.0007      2.7431      0.0099      1.1643  4.0534e-04 -2.1983e-03
#
#     z dered_u   z dered_g  z dered_r   z dered_i   z dered_z  z nObserve  \
# id
# 0      0.0003  2.3488e-05     0.0002  3.8455e-06  2.0594e-07      0.0003
# 1      0.1744  1.9104e-02     0.2052  1.2597e-02  7.5809e-03      0.0721
# 2      0.0475  4.8338e-03     0.0446  2.4830e-03  1.3416e-03      0.0104
# 3      0.1540  8.9650e-03     0.0867  6.0617e-03  3.9204e-03      0.0167
# 4      0.0434  2.7804e-03     0.0170  9.1963e-04  5.7181e-04      0.0270
#
#     z airmass_u     z class       z g_r       z u_g       z r_i   z i_z  \
# id
# 0    2.2191e-05  4.4896e-06  9.7243e-06  3.1515e-06  3.7322e-06  0.0003
# 1   -4.7893e-02  1.1072e-04  1.2286e-03  5.3855e-04  5.3806e-04  0.0329
# 2    3.9822e-02  3.9488e-04  5.4788e-04  2.5271e-04  2.9995e-04  0.0231
# 3    1.3162e-02  5.8669e-04  5.5951e-03 -2.3075e-04 -2.3590e-05  0.1518
# 4    3.1404e-03  7.2761e-04  1.6579e-03  7.8104e-05  6.2239e-05  0.0586
#
#          z u_r  z d_dered_u  z d_dered_g  z d_dered_r  z d_dered_i  \
# id
# 0   2.2235e-05   1.1669e-06   3.2960e-05  -3.7490e-08   1.4942e-07
# 1  -1.4200e-02  -5.8349e-04  -1.5419e-02  -8.7153e-06  -5.1123e-05
# 2  -1.9476e-03  -3.9487e-05  -1.9652e-03   4.4024e-05  -5.3424e-06
# 3  -6.1500e-03  -1.7133e-04  -1.8939e-03  -1.3410e-04  -2.6646e-05
# 4  -1.3188e-02  -1.8663e-04  -3.2124e-03  -7.9125e-05  -2.5252e-05
#
#     z d_dered_z  z d_dered_ug  z d_dered_gr  z d_dered_iz  z d_dered_ur  ...  \
# id                                                                       ...
# 0    1.7150e-05    7.9847e-06    2.8794e-06        0.0004    7.1979e-06  ...
# 1    1.9677e-03    1.1383e-04    5.0978e-04        0.0313    8.8495e-04  ...
# 2    9.0443e-04    7.0859e-04    2.9778e-04        0.0242    4.4839e-04  ...
# 3    9.6675e-03    9.4382e-04   -1.0655e-04        0.1594   -3.6516e-04  ...
# 4    2.4657e-03    1.2102e-03    1.3497e-05        0.0552    1.9944e-04  ...
#
#     d_dered_u d_dered_ug  d_dered_u d_dered_gr  d_dered_u d_dered_iz  \
# id
# 0             2.7258e-04            9.8297e-05                0.0129
# 1            -1.2837e-05           -5.7493e-05               -0.0035
# 2            -3.0646e-05           -1.2879e-05               -0.0010
# 3            -6.0435e-05            6.8228e-06               -0.0102
# 4            -5.5722e-04           -6.2147e-06               -0.0254
#
#     d_dered_u d_dered_ur  d_dered_u d_dered_ri  d_dered_g^2  \
# id
# 0             2.4572e-04                0.0104       0.0318
# 1            -9.9804e-05               -0.0070       0.0460
# 2            -1.9393e-05               -0.0005       0.0042
# 3             2.3382e-05                0.0016       0.0013
# 4            -9.1830e-05               -0.0108       0.0255
#
#     d_dered_g d_dered_r  d_dered_g d_dered_i  d_dered_g d_dered_z  \
# id
# 0           -3.6150e-05           1.4408e-04               0.0165
# 1            2.5973e-05           1.5236e-04              -0.0059
# 2           -9.4759e-05           1.1499e-05              -0.0019
# 3            9.4914e-05           1.8860e-05              -0.0068
# 4            6.2708e-04           2.0013e-04              -0.0195
#
#     d_dered_g d_dered_ug  d_dered_g d_dered_gr  d_dered_g d_dered_iz  \
# id
# 0                 0.0077            2.7766e-03                0.3641
# 1                -0.0003           -1.5193e-03               -0.0932
# 2                -0.0015           -6.4096e-04               -0.0522
# 3                -0.0007            7.5418e-05               -0.1129
# 4                -0.0096           -1.0697e-04               -0.4377
#
#     d_dered_g d_dered_ur  d_dered_g d_dered_ri  d_dered_r^2  \
# id
# 0                 0.0069                0.2940   4.1119e-08
# 1                -0.0026               -0.1852   1.4681e-08
# 2                -0.0010               -0.0235   2.1228e-06
# 3                 0.0003                0.0173   6.7204e-06
# 4                -0.0016               -0.1858   1.5446e-05
#
#     d_dered_r d_dered_i  d_dered_r d_dered_z  d_dered_r d_dered_ug  \
# id
# 0           -1.6389e-07          -1.8810e-05           -8.7576e-06
# 1            8.6118e-08          -3.3147e-06           -1.9175e-07
# 2           -2.5761e-07           4.3611e-05            3.4168e-05
# 3            1.3354e-06          -4.8450e-04           -4.7301e-05
# 4            4.9295e-06          -4.8133e-04           -2.3624e-04
#
#     d_dered_r d_dered_gr  d_dered_r d_dered_iz  d_dered_r d_dered_ur  \
# id
# 0            -3.1582e-06           -4.1417e-04           -7.8946e-06
# 1            -8.5874e-07           -5.2687e-05           -1.4907e-06
# 2             1.4359e-05            1.1685e-03            2.1621e-05
# 3             5.3400e-06           -7.9905e-03            1.8301e-05
# 4            -2.6348e-06           -1.0781e-02           -3.8932e-05
#
#     d_dered_r d_dered_ri  d_dered_i^2  d_dered_i d_dered_z  \
# id
# 0                -0.0003   6.5318e-07           7.4970e-05
# 1                -0.0001   5.0517e-07          -1.9444e-05
# 2                 0.0005   3.1262e-08          -5.2924e-06
# 3                 0.0012   2.6535e-07          -9.6272e-05
# 4                -0.0046   1.5732e-06          -1.5362e-04
#
#     d_dered_i d_dered_ug  d_dered_i d_dered_gr  d_dered_i d_dered_iz  \
# id
# 0             3.4905e-05            1.2587e-05                0.0017
# 1            -1.1248e-06           -5.0373e-06               -0.0003
# 2            -4.1464e-06           -1.7425e-06               -0.0001
# 3            -9.3989e-06            1.0611e-06               -0.0016
# 4            -7.5395e-05           -8.4088e-07               -0.0034
#
#     d_dered_i d_dered_ur  d_dered_i d_dered_ri  d_dered_z^2  \
# id
# 0             3.1465e-05            1.3327e-03       0.0086
# 1            -8.7444e-06           -6.1418e-04       0.0007
# 2            -2.6238e-06           -6.3975e-05       0.0009
# 3             3.6364e-06            2.4366e-04       0.0349
# 4            -1.2425e-05           -1.4603e-03       0.0150
#
#     d_dered_z d_dered_ug  d_dered_z d_dered_gr  d_dered_z d_dered_iz  \
# id
# 0             4.0062e-03            1.4447e-03                0.1895
# 1             4.3292e-05            1.9389e-04                0.0119
# 2             7.0195e-04            2.9499e-04                0.0240
# 3             3.4101e-03           -3.8498e-04                0.5761
# 4             7.3618e-03            8.2106e-05                0.3360
#
#     d_dered_z d_dered_ur  d_dered_z d_dered_ri  d_dered_ug^2  \
# id
# 0                 0.0036                0.1530    1.8652e-03
# 1                 0.0003                0.0236    2.5043e-06
# 2                 0.0004                0.0108    5.4995e-04
# 3                -0.0013               -0.0884    3.3292e-04
# 4                 0.0012                0.1426    3.6132e-03
#
#     d_dered_ug d_dered_gr  d_dered_ug d_dered_iz  d_dered_ug d_dered_ur  \
# id
# 0              6.7263e-04                 0.0882             1.6814e-03
# 1              1.1216e-05                 0.0007             1.9470e-05
# 2              2.3111e-04                 0.0188             3.4801e-04
# 3             -3.7585e-05                 0.0562            -1.2881e-04
# 4              4.0298e-05                 0.1649             5.9545e-04
#
#     d_dered_ug d_dered_ri  d_dered_gr^2  d_dered_gr d_dered_iz  \
# id
# 0                  0.0712    2.4256e-04                 0.0318
# 1                  0.0014    5.0230e-05                 0.0031
# 2                  0.0085    9.7124e-05                 0.0079
# 3                 -0.0086    4.2431e-06                -0.0063
# 4                  0.0700    4.4944e-07                 0.0018
#
#     d_dered_gr d_dered_ur  d_dered_gr d_dered_ri  d_dered_iz^2  \
# id
# 0              6.0635e-04                 0.0257        4.1718
# 1              8.7196e-05                 0.0061        0.1891
# 2              1.4625e-04                 0.0036        0.6432
# 3              1.4541e-05                 0.0010        9.5007
# 4              6.6411e-06                 0.0008        7.5245
#
#     d_dered_iz d_dered_ur  d_dered_iz d_dered_ri  d_dered_ur^2  \
# id
# 0                  0.0795                 3.3679    1.5157e-03
# 1                  0.0053                 0.3758    1.5137e-04
# 2                  0.0119                 0.2902    2.2022e-04
# 3                 -0.0218                -1.4580    4.9835e-05
# 4                  0.0272                 3.1937    9.8130e-05
#
#     d_dered_ur d_dered_ri  d_dered_ri^2
# id
# 0                  0.0642        2.7190
# 1                  0.0106        0.7467
# 2                  0.0054        0.1309
# 3                  0.0033        0.2238
# 4                  0.0115        1.3556
#
# [5 rows x 351 columns]

# %%
y = df[target_col].values[:320000]
df.drop(target_col, axis=1, inplace=True)
trn = df.iloc[:320000].values
tst = df.iloc[320000:].values
feature_name = df.columns.tolist()
print(y.shape, trn.shape, tst.shape)
# Out:
# (320000,) (320000, 350) (80000, 350)

# %%
cv = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=seed)

# %%
p_val = np.zeros((trn.shape[0], n_class))
p_tst = np.zeros((tst.shape[0], n_class))
for i, (i_trn, i_val) in enumerate(cv.split(trn, y), 1):
    print(f'training model for CV #{i}')
    clf = LogisticRegression(multi_class='multinomial')
    clf.fit(trn[i_trn], y[i_trn])
    p_val[i_val, :] = clf.predict_proba(trn[i_val])
    p_tst += clf.predict_proba(tst) / n_fold
# Out:
# training model for CV #1
# training model for CV #2
# training model for CV #3
# training model for CV #4
# training model for CV #5

# %%
print(f'{accuracy_score(y, np.argmax(p_val, axis=1)) * 100:.4f}%')
# Out:
# 90.0831%

# %%
print(p_val.shape, p_tst.shape)
# Out:
# (320000, 3) (80000, 3)

# %%
np.savetxt(p_val_file, p_val, fmt='%.6f', delimiter=',')
np.savetxt(p_tst_file, p_tst, fmt='%.6f', delimiter=',')

# %%
clf.coef_.shape
# Out:
# (3, 350)

# %%
imp = pd.DataFrame({'feature': df.columns, 'importance': clf.coef_[1, :].T})
imp = imp.sort_values('importance').set_index('feature')
imp.plot(kind='barh', figsize=(8, 32))
# Out:
# <AxesSubplot:ylabel='feature'>

# %%
sub = pd.read_csv(sample_file, index_col=0)
print(sub.shape)
sub.head()
# Out:
# (80000, 1)
#         class
# id
# 320000      0
# 320001      0
# 320002      0
# 320003      0
# 320004      0

# %%
sub[target_col] = np.argmax(p_tst, axis=1)
sub.head()
# Out:
#         class
# id
# 320000      2
# 320001      0
# 320002      2
# 320003      0
# 320004      2

# %%
sub[target_col].value_counts()
# Out:
# 2    42370
# 0    30991
# 1     6639
# Name: class, dtype: int64

# %%
sub.to_csv(sub_file)
